# %% [markdown]
# <a href="https://colab.research.google.com/github/Yunkaizdasick/Yunkaizdasick/blob/main/Project_Company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd
# !pip install --upgrade vnstock
from vnstock import *

from datetime import datetime

# %%
listing_companies()
# Out:
#      ticker comGroupCode                                          organName  \
# 0       SSI         HOSE                    Công ty Cổ phần Chứng khoán SSI
# 1       BCM         HOSE  Tổng Công ty Đầu tư và Phát triển Công nghiệp ...
# 2       VHM         HOSE                           Công ty Cổ phần Vinhomes
# 3       VIC         HOSE                     Tập đoàn Vingroup - Công ty CP
# 4       VRE         HOSE                      Công ty Cổ phần Vincom Retail
# ...     ...          ...                                                ...
# 1602    SDK        UPCOM                   Công ty Cổ phần Cơ khí Luyện Kim
# 1603    SRF         HOSE                          Công ty Cổ phần Searefico
# 1604    UEM        UPCOM        Công ty Cổ phần Cơ điện Uông Bí - Vinacomin
# 1605    VEA        UPCOM  Tổng Công ty Máy động lực và Máy nông nghiệp V...
# 1606    VES        UPCOM  Công ty Cổ phần Đầu tư và Xây dựng Điện MÊ CA ...
#
# ...

# %% [markdown]
# # Name of Company

# %%
name = input('Enter name of Company : ')
# Out:
# Enter name of Company : MBB

# %% [markdown]
# # Company Overview

# %%
company_overview(name)
# Out:
#   exchange shortName  industryID industryIDv2   industry industryEn  \
# 0     HOSE    MBBank         289         8355  Ngân hàng      Banks
#
#   establishedYear  noEmployees  noShareholders  foreignPercent  \
# 0            1994        15910          126621           0.232
#
#                     website  stockRating  deltaInWeek  deltaInMonth  \
# 0  http://www.mbbank.com.vn          4.2       -0.005        -0.028
#
#    deltaInYear  outstandingShare  issueShare companyType ticker
# 0       -0.011            5214.1      5214.1          NH    MBB

# %% [markdown]
# # Phân tích tài chính

# %% [markdown]
# ## Báo cáo tài chính

# %%
financial_flow(symbol=name , report_type='incomestatement', report_range='yearly')
# Out:
#       ticker  revenue  yearRevenueGrowth quarterRevenueGrowth costOfGoodSold  \
# index
# 2022     MBB    36023              0.375                 None           None
# 2021     MBB    26200              0.292                 None           None
# 2020     MBB    20278              0.127                 None           None
# 2019     MBB    18000              0.234                 None           None
# 2018     MBB    14583              0.300                 None           None
# 2017     MBB    11219              0.406                 None           None
# 2016     MBB     7979              0.090                 None           None
# 2015     MBB     7319              0.040                 None           None
# 2014     MBB     7036              0.149                 None           None
# 2013     MBB     6124             -0.072                 None           None
# 2012     MBB     6603              0.264                 None           None
# ...

# %% [markdown]
# ## Bảng cân đối kế toán

# %%
financial_flow(symbol= name , report_type='balancesheet', report_range='yearly')
# Out:
#       ticker shortAsset  cash shortInvest shortReceivable inventory longAsset  \
# index
# 2022     MBB       None  3744        None            None      None      None
# 2021     MBB       None  3475        None            None      None      None
# 2020     MBB       None  3109        None            None      None      None
# 2019     MBB       None  2344        None            None      None      None
# 2018     MBB       None  1737        None            None      None      None
# 2017     MBB       None  1842        None            None      None      None
# 2016     MBB       None  1520        None            None      None      None
# 2015     MBB       None  1236        None            None      None      None
# 2014     MBB       None  1233        None            None      None      None
# 2013     MBB       None  1035        None            None      None      None
# 2012     MBB       None   865        None            None      None      None
# ...

# %%
financial_ratio(symbol= name , report_range='yearly', is_all= True)
# Out:
# year                      2022   2021   2020   2019   2018   2017   2016  \
# ticker                     MBB    MBB    MBB    MBB    MBB    MBB    MBB
# priceToEarning             4.3    9.9    7.8    6.5    7.0   13.0    7.9
# priceToBook                0.9    2.0    1.3    1.3    1.2    1.5    0.9
# dividend                 0.034    NaN    NaN    NaN   0.06   0.06   0.06
# roe                      0.258  0.236  0.192  0.221  0.201  0.132  0.121
# roa                      0.026  0.023  0.018   0.02  0.018  0.012  0.012
# earningPerShare           3352   2435   1822   2070   1617    931    770
# bookValuePerShare        15268  11984  11049  10556   9044   7834   7037
# interestMargin           0.057   0.05  0.047  0.049  0.045  0.041  0.035
# nonInterestOnToi          0.21  0.291  0.259   0.27  0.254  0.191   0.19
# badDebtPercentage        0.011  0.009  0.011  0.012  0.013  0.012  0.013
# provisionOnBadDebt        2.38   2.68  1.341  1.105  1.123  0.959  1.032
# ...

# %% [markdown]
# ## Báo cáo lưu chuyển tiền tệ

# %%
financial_flow(symbol= name , report_type='cashflow', report_range='yearly')
# Out:
#       ticker  investCost  fromInvest  fromFinancial  fromSale  freeCashFlow
# index
# 2022     MBB       -1748       -1443           2120      1876           0.0
# 2021     MBB       -1260       -1124              0      4468           0.0
# 2020     MBB        -823        -719           2293     14740           0.0
# 2019     MBB        -702        -620          -1909       893           0.0
# 2018     MBB        -484        -418          -1093      2605           0.0
# 2017     MBB        -503         586           -883     24003           0.0
# 2016     MBB        -561         378            -22     -3509           0.0
# 2015     MBB        -287        -439           3860      2447           0.0
# 2014     MBB        -361        -291           -801      8684           0.0
# 2013     MBB        -639        -572            194    -14986           0.0
# 2012     MBB        -189          70           1354    -17080           0.0
# ...

# %% [markdown]
# # Phân tích kỹ thuật

# %% [markdown]
# ## Truy xuất giá cổ phiếu

# %%
start_day = input('Nhập Start Day : ')
end_day = input('Nhập End Day : ')
price_board =  pd.DataFrame(stock_historical_data(symbol= name ,
                            start_date= start_day,
                            end_date= end_day, resolution='1D', type='stock')).set_index('time')
price_board
# Out:
# Nhập Start Day : 2023-01-01
# Nhập End Day : 2023-08-27
#              open   high    low  close    volume ticker
# time
# 2023-01-03  14590  15270  14590  15270   7538000    MBB
# 2023-01-04  15350  15480  15230  15230   7750200    MBB
# 2023-01-05  15270  15480  15100  15430   7746900    MBB
# 2023-01-06  15310  15900  15270  15480  10917100    MBB
# 2023-01-09  15690  15690  15430  15480   5950900    MBB
# ...           ...    ...    ...    ...       ...    ...
# 2023-08-21  18000  18350  17850  18150   9217300    MBB
# 2023-08-22  18300  18300  17750  18200   8055700    MBB
# 2023-08-23  18300  18300  18000  18000   5796400    MBB
# 2023-08-24  18100  18350  18000  18250   6694700    MBB
# 2023-08-25  18200  18200  18100  18100   4769800    MBB
#
# [161 rows x 6 columns]

# %% [markdown]
# ## Biến động giá cổ phiếu

# %%
plt.plot(price_board['close'])
plt.ylabel('Giá cổ phiếu')
# Out:
# Text(0, 0.5, 'Giá cổ phiếu')
